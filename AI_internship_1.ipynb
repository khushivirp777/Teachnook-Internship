# %% [markdown]
# Linear

# %%
import pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('advertising.csv')

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['TV'].plot(kind='hist', bins=20, title='TV')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Radio'].plot(kind='hist', bins=20, title='Radio')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Newspaper'].plot(kind='hist', bins=20, title='Newspaper')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Sales'].plot(kind='hist', bins=20, title='Sales')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='TV', y='Radio', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Radio', y='Newspaper', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Newspaper', y='Sales', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['TV'].plot(kind='line', figsize=(8, 4), title='TV')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Radio'].plot(kind='line', figsize=(8, 4), title='Radio')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Newspaper'].plot(kind='line', figsize=(8, 4), title='Newspaper')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Sales'].plot(kind='line', figsize=(8, 4), title='Sales')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import seaborn as sns

# %%
sns.pairplot(df,x_vars=['TV',"Radio","Newspaper"], y_vars="Sales", height=4)
#scatter plot

# %%
corr = df.corr()
corr
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
x = df.drop('Sales', axis=1)
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y = df['Sales']
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_hat = lr.predict(x)
y_hat
# Out:
# array([21.22097209, 11.26824775, 10.49620897, 17.31244651, 15.64413685,
#        10.35633677, 11.2732847 , 13.27062458,  5.31839603, 15.78871013,
#         8.8527202 , 18.88400523,  9.69879662, 10.74921373, 19.27328852,
#        20.38554445, 12.27105794, 24.20214502, 10.5924398 , 15.20872794,
#        19.49794066, 18.10414656,  7.06177654, 18.87221072,  9.37145421,
#        19.31996936, 15.54479137, 19.49216302, 21.07865408, 10.19471067,
#        23.61492832, 12.64683045, 10.08782551, 21.2260486 ,  9.98787085,
#        20.89407055, 23.84503494, 13.99342411,  9.8404516 , 21.08344935,
#        18.04712878, 17.84885818, 23.57494339, 16.79762772,  8.75617872,
#        16.57668108, 10.58020572, 22.13342743, 18.70257411,  9.53181337,
#        15.84670856, 11.11990058, 20.88243422, 19.53008343, 22.01500291,
#        20.76038994,  8.04320903, 14.10063486, 21.4222098 , 19.25650785,
#         7.75915886, 23.43911942, 19.32168181, 13.3867616 , 16.35231896,
#         9.37729644,  8.97313482, 13.7643628 , 20.49677834, 21.13545307,
#        18.75250649, 12.14402868,  9.62178972, 12.29082115, 18.88048094,
#        10.25121926,  6.30053312, 14.24014196,  8.1216232 , 11.77249775,
#        11.64919966, 18.13231302, 10.90792515, 13.12271953, 20.86169623,
#        17.13492417, 11.72724142, 15.01773541, 12.18585509, 15.73518229,
#        12.46462002,  6.35385195, 20.08231542, 22.21538326, 11.97427675,
#        16.91511512, 15.76009495, 16.94655913, 24.94140428, 16.4635515 ,
#        17.21068667, 24.68086584, 20.96872721, 16.70191561, 21.26603007,
#        17.117858  ,  7.17325114,  9.58691025,  5.38975714, 21.41075554,
#        17.81535602, 21.85850312, 15.83987218, 18.24477648, 13.90202178,
#        12.47673434, 13.74268711,  8.87535042, 15.4438881 ,  7.40087704,
#        15.20145315,  7.98754856, 17.08301809, 15.03380429, 20.60147616,
#        10.64410416,  9.22913323,  8.99476371, 21.86366378,  9.16857418,
#         8.90340499, 19.38888188,  7.99360692, 20.19198592, 10.78643994,
#        12.28676609, 10.19510558, 22.63930843,  9.74450543, 19.3900734 ,
#        10.44479522, 18.98449095, 20.19558086, 10.94160634, 11.45948342,
#        12.47019032, 18.48158513, 23.12426769, 11.01020756,  9.8263967 ,
#        21.40779104, 12.12822036, 17.88150523, 18.21228932, 17.11095629,
#         6.09147928, 14.40908701, 12.92836006,  9.22565677, 13.77606971,
#        15.96404812, 13.13831936, 16.82802417, 17.46713823, 12.58090014,
#        17.78492754,  9.63019994, 16.4474296 , 18.89730805, 21.24042066,
#         8.59480345, 15.8336908 ,  7.84869225, 14.55779863, 17.10206692,
#        24.94755122, 21.38770686, 14.73822063, 19.94432942, 14.71726516,
#        13.43232243, 17.10853074,  8.30485298, 24.90888356, 20.73265903,
#        20.61884334, 12.45394152, 18.10675693, 21.68517626,  6.94582943,
#        11.1754297 ,  9.89340771,  6.01090333, 18.20194019, 16.58691507,
#         7.10548951, 10.28094143, 15.25928683, 24.58221952, 18.18512048])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.2, random_state=42)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 175  276.9   48.9       41.8
# 134   36.9   38.6       65.6
# 167  206.8    5.2       19.4
# 183  287.6   43.0       71.8
# 63   102.7   29.6        8.4
# 54   262.7   28.8       15.9
# 107   90.4    0.3       23.2
# 50   199.8    3.1       34.6
# 196   94.2    4.9        8.1
# 58   210.8   49.6       37.7
# 48   227.2   15.8       49.9
# 88    88.3   25.5       73.4
# 21   237.4    5.1       23.5
# 57   136.2   19.2       16.6
# 160  172.5   18.1       30.7
# 192   17.2    4.1       31.6
# 129   59.6   12.0       43.1
# 37    74.7   49.4       45.7
# 157  149.8    1.3       24.3
# 193  166.8   42.0        3.6
# 1     44.5   39.3       45.1
# 52   216.4   41.7       39.6
# 149   44.7   25.8       20.6
# 130    0.7   39.6        8.7
# 151  121.0    8.4       48.7
# 103  187.9   17.2       17.9
# 99   135.2   41.7       45.9
# 116  139.2   14.3       25.6
# 87   110.7   40.6       63.2
# 74   213.4   24.6       13.1
# 121   18.8   21.7       50.4
# 199  232.1    8.6        8.7
# 20   218.4   27.7       53.4
# 188  286.0   13.9        3.7
# 71   109.8   14.3       31.7
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4

# %%
y_train
# Out:
# 175    27.0
# 134    10.8
# 167    17.2
# 183    26.2
# 63     14.0
# 54     20.2
# 107    12.0
# 50     16.4
# 196    14.0
# 58     23.8
# 48     19.8
# 88     12.9
# 21     17.5
# 57     13.2
# 160    16.4
# 192     5.9
# 129     9.7
# 37     14.7
# 157    10.1
# 193    19.6
# 1      10.4
# 52     22.6
# 149    10.1
# 130     1.6
# 151    11.6
# 103    19.7
# 99     17.2
# 116    12.2
# 87     16.0
# 74     17.0
# 121     7.0
# 199    18.4
# 20     18.0
# 188    20.9
# 71     12.4
# 106     7.2
# 14     19.0
# 92     19.4
# 179    17.6
# 102    19.8
# Name: Sales, dtype: float64

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# ..     ...    ...        ...
# 59   210.7   29.5        9.3
# 171  164.5   20.9       47.4
# 131  265.2    2.9       43.0
# 17   281.4   39.6       55.8
# 72    26.8   33.0       19.3
#
# [160 rows x 3 columns]

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
#        ...
# 59     18.4
# 171    17.5
# 131    17.7
# 17     24.4
# 72      8.8
# Name: Sales, Length: 160, dtype: float64

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)
y_pred
# Out:
# array([17.32102034, 20.76952621, 24.42176613,  8.84760332, 21.54945944,
#        12.49128592, 21.23492319,  8.18546594, 17.38225926, 16.77724474,
#         8.11034878,  8.15491482, 19.24863853,  7.21748548, 12.62522911,
#        15.11592505,  7.6700891 , 17.89162832, 10.74199495, 20.577452  ,
#        21.60520451, 13.21114237, 10.17938417, 23.23592891,  8.78940044,
#         7.50179876, 21.06075696, 13.55858684, 10.50179864,  7.01147759,
#        16.11334896, 10.17527754, 21.25486097, 10.5296208 , 22.2027978 ,
#        21.19572103, 11.38066332, 23.62407471, 12.20803364,  5.9308635 ,
#        11.7407816 , 15.19457127,  9.52538593,  9.00079267, 17.41864772,
#         6.65006963, 10.18162528, 15.0876162 , 11.06150239, 11.23646056,
#        13.52999934, 14.58034271, 10.32479399,  8.90195866,  8.61731957,
#        12.46181092,  9.99208562, 25.7301328 ,  7.21442018, 15.82525446,
#        21.59678369, 17.05048096, 12.75657391,  9.71412941, 21.37069835,
#         6.88826465, 23.7350999 ,  6.48450974, 12.3147778 ,  9.2852988 ,
#        10.69871264,  8.67098914, 17.03034904, 18.06842951, 16.06425854,
#        18.27338829, 15.25221612, 18.95718165, 18.06318554, 22.05076698,
#        10.43702961, 13.88995818, 10.62096673, 18.10309875,  9.39834868,
#        17.98839278, 13.13434178, 23.79645256, 10.2466005 , 24.16478079,
#         6.95709092, 19.83661973, 26.3396353 , 21.32187624, 18.79517963,
#        16.15805143, 13.88902087, 10.77537969, 19.87372216, 15.45767082,
#        16.4035485 , 10.14774361, 20.58004345, 12.36807077, 21.48273   ,
#        11.53100848,  8.65478281, 19.7809364 , 15.64918526, 18.72691428,
#         8.89712432, 22.09622494, 25.58651347, 18.33371292, 19.08768291,
#        14.60821382, 16.14295893,  8.50760115, 17.10486298, 21.3974482 ,
#        18.36180865,  5.05077379,  5.29580322, 14.38473128, 19.86405409,
#        19.25645715, 21.23860002, 23.55295043, 18.85281914, 21.36247194,
#        19.66329614, 22.21109791, 11.65546132, 17.02783518, 17.17863166,
#         9.20552119, 17.66800985, 17.37840412, 19.96827937, 20.68473786,
#        13.37836129, 20.62190463, 20.5390946 ,  9.4809633 , 11.26605099,
#         9.68502711, 12.96186296, 18.75090097,  6.1842137 , 12.75017939,
#        21.63455921, 17.5804447 , 15.74880163,  4.5559417 , 10.39211133,
#        19.18362808, 16.25812715, 20.319791  , 25.0555663 ,  8.9315593 ])

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 1.3095587464110352

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 2.863384751836487
